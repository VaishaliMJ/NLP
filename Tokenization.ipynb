# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/vaishali/Desktop/NLP/.venv/lib/python3.12/site-packages (3.9.4)
# Requirement already satisfied: click in /Users/vaishali/Desktop/NLP/.venv/lib/python3.12/site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in /Users/vaishali/Desktop/NLP/.venv/lib/python3.12/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/vaishali/Desktop/NLP/.venv/lib/python3.12/site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in /Users/vaishali/Desktop/NLP/.venv/lib/python3.12/site-packages (from nltk) (4.68.3)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /Users/vaishali/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/vaishali/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
corpus="""Hello,Welcome to NLP Tutorials.
This is practise code !

"""

# %%
print(corpus)
# Out:
# Hello,Welcome to NLP Tutorials.
# This is practise code !

# %%
#Tokenization
#Sentence--->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
   print(sentence)
# Out:
# Hello,Welcome to NLP Tutorials.
# This is practise code !

# %%
#Sentence--->Word
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'NLP',
#  'Tutorials',
#  '.',
#  'This',
#  'is',
#  'practise',
#  'code',
#  '!']

# %%
# Sentence to word
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', ',', 'Welcome', 'to', 'NLP', 'Tutorials', '.']
# ['This', 'is', 'practise', 'code', '!']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'NLP',
#  'Tutorials',
#  '.',
#  'This',
#  'is',
#  'practise',
#  'code',
#  '!']

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'Welcome',
#  'to',
#  'NLP',
#  'Tutorials.',
#  'This',
#  'is',
#  'practise',
#  'code',
#  '!']
